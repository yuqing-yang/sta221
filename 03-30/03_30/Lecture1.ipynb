# %% [markdown]
# # STA 221
# $$ x=5$$

# %% [markdown]
# In this lecture, we will learn about basic operations in Python. We will also learn how to use the package numpy for numerical computing with Python.

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Strings -- hashtag is used for comment
my_string = "Hello World!"
print(my_string)
print(my_string.upper())




#Concatenation 

first = "Hello"
last  = "World"
full1 = first + last
full2 = first +'sta141c'+last
full3 = first +' '+last
full4 = first +' '+last+'!'
print(full1)
print(full2)
print(full3)
print(full4)
# Out:
# Hello World!
# HELLO WORLD!
# HelloWorld
# Hellosta141cWorld
# Hello World
# Hello World!

# %%
#Arithmetic Operations
sum=3+2
print(sum)
print(22/7) # division
print(22//7) # floor division
print(15%4) # remainder
print(3*2)
# Out:
# 5
# 3.142857142857143
# 3
# 3
# 6

# %%
#Logical Operations
x1 = 5
y1 = 7
x2 = 'Hello'
y2 = 'Hello'
x3 = [1,2,3]
y3 = [2,1,3]

# Output: False
print(x1 is not y1) 

# Output: True
print(x2 is y2)

# Output: False
print(x3 is y3) # Difference between 'equal' and 'identitical'

7 % 2 == 0


2 < 3
# Out:
# True
# True
# False
# False
# True

# %%
# Lists

# empty list
my_list = []

# list of integers
my_list = [1, 2, 3, 4, 5]

print(list(reversed(my_list))) #reverse list


# list with mixed datatypes
my_list = [1, "Hello", 3.4]

print(my_list[1])

# nested list
nested_list = ["mouse", [8, 4, 6], ['mouse', "cat", "dog"]]

# Output: m
print(nested_list[0][0])    

# Output: 4
print(nested_list[1][1])

# Output: dog
print(nested_list[2][2][1])
# Out:
# [5, 4, 3, 2, 1]
# Hello
# m
# 4
# o

# %%
#for loop

students = ['beRnIce', 'AARON', 'cody']

#c =list(students)

for i in students:
    print("Hello, " + i.upper() + "!") # .title converts first character to CAPS and rest of the characters to small.
    
#for temp in c:
#    print("Hello, " + temp.upper() + "!")
# Out:
# Hello, BERNICE!
# Hello, AARON!
# Hello, CODY!

# %%
#for t in range(6): #range function
#    print("hello")
#    print("bye")
    

my_array=[10,2,39,4,15,81,7,97]


sum=0

for x in range(8):
    sum=sum+my_array[x]
    
    
print(sum)
# Out:
# 255

# %%
#IF-ELSE statement
a = 3
b = 20
if b > a:
    for i in range(10):
        print("b is greater than a") ##pay attention to indentation
    print ("adsfadsfafa")
else:
    print("a is greater than b")
# Out:
# b is greater than a
# b is greater than a
# b is greater than a
# b is greater than a
# b is greater than a
# b is greater than a
# b is greater than a
# b is greater than a
# b is greater than a
# b is greater than a
# adsfadsfafa

# %%
i = 0
while i < 6:
    i += 1 
    if i == 3:
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %%
print(sorted([3,1,5,2,4]))

vowel = ('e', 'a', 'u', 'o', 'i')
print(sorted(vowel))
# Out:
# [1, 2, 3, 4, 5]
# ['a', 'e', 'i', 'o', 'u']

# %%
import numpy as np ##NUMPY for mumerical computing in python
#a = np.array([1,2,3,4,5,6]) 
#a
#type(a)
#a.shape

#a = np.array([[1,2], [3,4],[2,3]])

#a

#a.shape

#a = np.arange(5)
#a

#a = np.ones((2, 2))
#a

#b = np.zeros((2, 2))
#b

#c = np.eye(7)
#c


#d = np.diag(np.array([1, 2,20,40]))
#d    

r = np.random.rand(2,2)
r
# Out:
# array([[0.05922102, 0.07399513],
#        [0.90604274, 0.46074834]])

# %%
a = np.array([[1, 2], [3, 4]])
a.dtype #array data type

b = np.random.random((2, 2))
b.dtype

a = a+b
a.dtype
# Out:
# dtype('int64')
# dtype('float64')
# dtype('float64')

# %%
#Convert array types
a = np.random.rand(2,2) * 5
a

b = a.astype(int)
b

b.dtype #not just taking the integer part; the data type itself is changed.
# Out:
# array([[1.42204741, 3.64883144],
#        [0.90455266, 3.70980062]])
# array([[1, 3],
#        [0, 3]])
# dtype('int64')

# %%
#indexing
a = np.diag(np.arange(3))
a

a[1, 1] 

a[2, 1] = 10
a

a[1]  # index the entire row
# Out:
# array([[0, 0, 0],
#        [0, 1, 0],
#        [0, 0, 2]])
# 1
# array([[ 0,  0,  0],
#        [ 0,  1,  0],
#        [ 0, 10,  2]])
# array([0, 1, 0])

# %%
#more fancy indexing
r = 10*np.random.rand(5,5)
r = r.astype(int)
r

r[1]
r[:,1]
r[2:, 2:]
r[2:, 3:]


r[1::3, ::2]

#For more fancy indexing schemes see http://scipy-lectures.org/intro/numpy/array_object.html#indexing-and-slicing
# Out:
# array([[8, 1, 7, 3, 4],
#        [8, 0, 4, 9, 1],
#        [3, 9, 0, 5, 7],
#        [3, 5, 2, 7, 9],
#        [5, 6, 8, 6, 7]])
# array([8, 0, 4, 9, 1])
# array([1, 0, 9, 5, 6])
# array([[0, 5, 7],
#        [2, 7, 9],
#        [8, 6, 7]])
# array([[5, 7],
#        [7, 9],
#        [6, 7]])
# array([[8, 4, 1],
#        [5, 8, 7]])

# %%
#Boolean Masking
a = np.array([[1,2], [3,4], [5,6]])
a

bool_idx = (a > 2)
bool_idx

b = a[bool_idx]
b
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])
# array([[False, False],
#        [ True,  True],
#        [ True,  True]])
# array([3, 4, 5, 6])

# %%
#arithmetics on array

a = np.array([[1,2,3], [4,5,6]])
b = np.array([[4,5,6], [1,2,3]])

a
b


a+b
a-b
a*b
a/b
a**b #exponentiation
a + 1
a + np.array([[1], [2]])
a + np.array([1, 2, 3])
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])
# array([[4, 5, 6],
#        [1, 2, 3]])
# array([[5, 7, 9],
#        [5, 7, 9]])
# array([[-3, -3, -3],
#        [ 3,  3,  3]])
# array([[ 4, 10, 18],
#        [ 4, 10, 18]])
# array([[0.25, 0.4 , 0.5 ],
#        [4.  , 2.5 , 2.  ]])
# array([[  1,  32, 729],
#        [  4,  25, 216]])
# array([[2, 3, 4],
#        [5, 6, 7]])
# array([[2, 3, 4],
#        [6, 7, 8]])
# array([[2, 4, 6],
#        [5, 7, 9]])

# %%
#more operations on arrays
a = np.array([[1,2,3], [4,5,6]])
a.sum() #sum of all entries
a.sum(axis=0) #sum along colums
a.sum(axis=1) #sum along rows


a.min() # min of all entries
a.min(axis=0) #sum along colums
a.min(axis=1) #sum along rows
# Out:
# 21
# array([5, 7, 9])
# array([ 6, 15])
# 1
# array([1, 2, 3])
# array([1, 4])

# %%
#reshaping arrays
np.arange(6)
a = np.arange(6).reshape((3, 2))
a

a = np.array([[1, 2, 3], [4, 5, 6]])
a
a.reshape((3, 2))

a.T #transpose
# Out:
# array([0, 1, 2, 3, 4, 5])
# array([[0, 1],
#        [2, 3],
#        [4, 5]])
# array([[1, 2, 3],
#        [4, 5, 6]])
# array([[1, 2],
#        [3, 4],
#        [5, 6]])
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
import matplotlib.pyplot as plt

x = np.random.random((80, 80, 3))
plt.imshow(x)

# %%
plt.imshow(x, interpolation='bicubic')

# %%
plt.imshow(x.mean(axis=-1), cmap='Reds')
plt.xticks(range(0, x.shape[1], 4))
plt.yticks(range(0, x.shape[0], 4))
plt.grid(color='white')
ax = plt.gca()
ax.set_xticklabels([])
ax.set_yticklabels([])
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
pass
# Out:
# ([<matplotlib.axis.XTick at 0x1129a72e8>,
# ...
#  <a list of 20 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1129a7fd0>,
# ...
#  <a list of 20 Text yticklabel objects>)
# []
# []

# %%
#line plots
import matplotlib.pyplot as plt
import numpy as np ##NUMPY for mumerical computing in python

import scipy.stats as stats
x = np.linspace(-5, 5, 100)
y = stats.norm().pdf(x)


plt.plot(x, y)

# %%
xs = np.random.multivariate_normal([0,0], np.array([[1,0.5],[0.5, 1]]), 100) #generate 100 2-dimensional multivariate normal vector
d = np.linalg.norm(xs, ord=2, axis=1)
plt.scatter(xs[:, 0], xs[:, 1], c=d, cmap='jet') #scatter plot
plt.axis('square')
plt.xticks([])
plt.yticks([])
pass
# Out:
# (-1.816874865911891,
#  4.092470200597117,
#  -3.0781866844440184,
#  2.8311583820649897)
# ([], <a list of 0 Text xticklabel objects>)
# ([], <a list of 0 Text yticklabel objects>)

# %%
plt.hist(xs, bins=15, alpha=0.9) #histogram
# Out:
# ([array([ 0.,  0.,  0.,  3.,  6.,  8., 15., 17., 20., 11., 11.,  5.,  2.,
#           0.,  2.]),
#   array([ 2.,  1.,  2.,  2.,  5., 12., 19., 16., 10., 10.,  7.,  7.,  5.,
#           1.,  1.])],
#  array([-2.79578318, -2.41484519, -2.0339072 , -1.65296922, -1.27203123,
#         -0.89109324, -0.51015525, -0.12921726,  0.25172072,  0.63265871,
#          1.0135967 ,  1.39453469,  1.77547268,  2.15641067,  2.53734865,
#          2.91828664]),
#  <a list of 2 Lists of Patches objects>)

# %%
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt


# Generate some data for this demonstration.
data = norm.rvs(10.0, 0.06, size=100000)

# Fit a normal distribution to the data:
mu, std = norm.fit(data)

# Plot the histogram.
plt.hist(data, bins=50, density=True, alpha=0.6, color='b')

# Plot the PDF.
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mu, std)
plt.plot(x, p, 'k', linewidth=2)

#plt.savefig("fw.pdf", bbox_inches='tight')
# Out:
# (array([9.71913297e-04, 2.91573989e-03, 9.71913297e-04, 5.83147978e-03,
#         9.71913297e-03, 1.84663526e-02, 3.30450521e-02, 6.12305377e-02,
#         9.03879366e-02, 1.60365694e-01, 3.02265035e-01, 4.08203585e-01,
#         5.44271446e-01, 8.60143268e-01, 1.14394195e+00, 1.56380849e+00,
#         2.15959135e+00, 2.76509333e+00, 3.31714008e+00, 3.96540625e+00,
#         4.83818439e+00, 5.39509071e+00, 5.86452483e+00, 6.28827903e+00,
#         6.51765057e+00, 6.60901042e+00, 6.54680797e+00, 6.21344171e+00,
#         5.77608072e+00, 5.13947751e+00, 4.57285206e+00, 3.78171464e+00,
#         3.07318984e+00, 2.46671595e+00, 1.94577042e+00, 1.44815081e+00,
#         1.03703149e+00, 7.73642984e-01, 5.25805093e-01, 3.70298966e-01,
#         2.29371538e-01, 1.39955515e-01, 1.03022809e-01, 5.34552313e-02,
#         3.30450521e-02, 1.16629596e-02, 1.16629596e-02, 1.94382659e-03,
#         5.83147978e-03, 3.88765319e-03]),
# ...
